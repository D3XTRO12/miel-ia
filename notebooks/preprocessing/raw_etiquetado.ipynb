# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("emg_all_features_labeled.csv", keep_default_na=False)
df.head()
# Out:
#    0.029437  0.051465  0.089432  0.016893  0.014127  0.017735  0.019645  \
# 0  0.035060  0.025699  0.025286  0.020039  0.012505  0.016996  0.017674
# 1  0.043982  0.033187  0.071985  0.018900  0.016712  0.025793  0.025291
# 2  0.032677  0.031038  0.033345  0.020213  0.016290  0.028113  0.027834
# 3  0.032101  0.029580  0.035939  0.037279  0.014564  0.022579  0.018042
# 4  0.034332  0.029158  0.027977  0.025456  0.015080  0.023670  0.025631
#
#    0.014079  0.030692  0.052209  ...  2.3516  2  3  6  0  0.1  1  1.1  0.2  \
# 0  0.014974  0.036073  0.027496  ...  2.3906  3  2  2  2    0  0    1    1
# 1  0.020268  0.044961  0.034351  ...  2.7813  3  2  4  0    1  2    1    2
# 2  0.019944  0.033778  0.032369  ...  2.4141  2  1  1  0    0  2    2    1
# 3  0.015792  0.033035  0.030936  ...  2.3516  2  1  6  4    0  1    0    0
# 4  0.018851  0.035562  0.030472  ...  2.6641  2  2  1  2    0  2    2    2
#
#    1.2
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
#
# [5 rows x 81 columns]

# %%
df.columns
# Out:
# Index(['0.029437', '0.051465', '0.089432', '0.016893', '0.014127', '0.017735',
#        '0.019645', '0.014079', '0.030692', '0.052209', '0.08977', '0.019609',
#        '0.016973', '0.020182', '0.021575', '0.017081', '-0.16406', '-0.28906',
#        '-0.53906', '-0.054688', '-0.054688.1', '-0.11719', '-0.125',
#        '-0.054688.2', '0.09375', '0.16406', '0.3125', '0.03125', '0.039063',
#        '0.046875', '0.0625', '0.03125.1', '53', '49', '56', '39', '21', '27',
#        '31', '23', '0.074323', '0.11297', '0.21297', '0.050417', '0.039271',
#        '0.047031', '0.05099', '0.036354', '0.03125.2', '0.054688', '0.03125.3',
#        '0.039063.1', '0.03125.4', '0.046875.1', '0.023438', '0.023438.1',
#        '0.017896', '0.02666', '0.04566', '0.013029', '0.010639', '0.011585',
#        '0.011896', '0.010152', '4.3672', '6.6563', '11.773', '2.9219',
#        '2.3594', '2.6797', '2.8047', '2.3516', '2', '3', '6', '0', '0.1', '1',
#        '1.1', '0.2', '1.2'],
#       dtype='object')

# %%
# Definimos los nombres de los features
features = ['standard_deviation', 'root_mean_square', 'minimum', 'maximum',
            'zero_crossings', 'average_amplitude_change', 'amplitude_first_burst',
            'mean_absolute_value', 'wave_form_length', 'willison_amplitude']

# Ahora generamos las etiquetas para los 80 features (8 electrodos x 10 features)
column_names = []
for feature in features:
    for i in range(1, 9):  # 8 electrodos
        column_names.append(f'{feature}_e{i}')

# Agregamos la columna de etiqueta final
column_names.append('label')

# %%
# Asignamos los nombres a las columnas
df.columns = column_names

# Verificamos el cambio
df.head()
# Out:
#    standard_deviation_e1  standard_deviation_e2  standard_deviation_e3  \
# 0               0.035060               0.025699               0.025286
# 1               0.043982               0.033187               0.071985
# 2               0.032677               0.031038               0.033345
# 3               0.032101               0.029580               0.035939
# 4               0.034332               0.029158               0.027977
#
#    standard_deviation_e4  standard_deviation_e5  standard_deviation_e6  \
# 0               0.020039               0.012505               0.016996
# 1               0.018900               0.016712               0.025793
# 2               0.020213               0.016290               0.028113
# 3               0.037279               0.014564               0.022579
# 4               0.025456               0.015080               0.023670
#
#    standard_deviation_e7  standard_deviation_e8  root_mean_square_e1  \
# ...

# %%
# Diccionario de etiquetas
label_map = {
    1: 'index_finger',
    2: 'middle_finger',
    3: 'ring_finger',
    4: 'little_finger',
    5: 'thumb',
    6: 'rest',
    7: 'victory_gesture'
}

# Creamos una nueva columna con el nombre de la etiqueta
df['gesture'] = df['label'].map(label_map)

# Mostramos las primeras filas con la nueva columna
df.head()
# Out:
#    standard_deviation_e1  standard_deviation_e2  standard_deviation_e3  \
# 0               0.035060               0.025699               0.025286
# 1               0.043982               0.033187               0.071985
# 2               0.032677               0.031038               0.033345
# 3               0.032101               0.029580               0.035939
# 4               0.034332               0.029158               0.027977
#
#    standard_deviation_e4  standard_deviation_e5  standard_deviation_e6  \
# 0               0.020039               0.012505               0.016996
# 1               0.018900               0.016712               0.025793
# 2               0.020213               0.016290               0.028113
# 3               0.037279               0.014564               0.022579
# 4               0.025456               0.015080               0.023670
#
#    standard_deviation_e7  standard_deviation_e8  root_mean_square_e1  \
# ...

# %%
# Guardamos el dataset etiquetado
df.to_csv('dataset_etiquetado.csv', index=False)

# %%
df_etiquetas = pd.read_csv("dataset_etiquetado.csv", keep_default_na=False)
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6822 entries, 0 to 6821
# Data columns (total 82 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   standard_deviation_e1        6822 non-null   float64
#  1   standard_deviation_e2        6822 non-null   float64
#  2   standard_deviation_e3        6822 non-null   float64
#  3   standard_deviation_e4        6822 non-null   float64
#  4   standard_deviation_e5        6822 non-null   float64
#  5   standard_deviation_e6        6822 non-null   float64
#  6   standard_deviation_e7        6822 non-null   float64
#  7   standard_deviation_e8        6822 non-null   float64
#  8   root_mean_square_e1          6822 non-null   float64
#  9   root_mean_square_e2          6822 non-null   float64
#  10  root_mean_square_e3          6822 non-null   float64
#  11  root_mean_square_e4          6822 non-null   float64
# ...
